# %%
import torchvision
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from torchvision import transforms
mnist = torchvision.datasets.MNIST(root='.', download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 69605496.76it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 29473404.82it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 100375782.24it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 16199429.22it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw

# %%
def continue_training():
    network.train()
    for i in range(10):
        correct = 0
        for data, target in train_loader:
            optimizer.zero_grad()
            output = network(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()

            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    score = float(correct/len(train_loader.dataset))
    accuracy_train.append(score)
    print('Iteration', len(accuracy_train), 'Training accuracy:', score)

    correct = 0
    network.eval()
    for data, target in test_loader:
        output = network(data)
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).sum()
    score = float(correct/len(test_loader.dataset))
    accuracy_test.append(score)
    print('Iteration', len(accuracy_test), 'Testing accuracy:', score)

# %%
class Net(nn.Module):
    def __init__(self, drop):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 12, kernel_size=5)
        self.conv2 = nn.Conv2d(12, 20, kernel_size=5)
        self.fc1 = nn.Linear(320, 50)
        self.dropout = nn.Dropout(drop)  # Dropout layer with 50% dropout probability
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # Applying dropout after the first fully connected layer
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)  # Make sure to specify the dimension for log_softma

# %%
mnist = torchvision.datasets.MNIST(root='.', download=True, transform=torchvision.transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(torch.utils.data.Subset(mnist, np.arange(5000)),
                                        batch_size=1000, shuffle=True)
test_loader = torch.utils.data.DataLoader(torch.utils.data.Subset(mnist, np.arange(5000, 10000)),
                                        batch_size=1000, shuffle=True)



final_testing_accuracy = []
drop_rates = np.linspace(0.1, 0.8, 10)

for r in drop_rates:
    total_accuracy = 0
    for j in range(5):
        network = Net(r)
        optimizer = optim.SGD(network.parameters(), lr=0.1, momentum=0.5)
        accuracy_train = []
        accuracy_test = []
        for i in range(2):
            continue_training()

        total_accuracy += (accuracy_test[1] - accuracy_test[0])
        print(accuracy_test[1] - accuracy_test[0])
    final_testing_accuracy.append(total_accuracy / 5)


plt.figure(figsize=(12,4))
plt.plot(drop_rates, final_testing_accuracy)
plt.xlabel('Dropout Probability')
plt.ylabel('Accuracy Difference Between First Two Training Iterations')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.8289999961853027
# Iteration 1 Testing accuracy: 0.8532000184059143
# Iteration 2 Training accuracy: 0.9276000261306763
# Iteration 2 Testing accuracy: 0.9290000200271606
# 0.07580000162124634
# Iteration 1 Training accuracy: 0.7680000066757202
# Iteration 1 Testing accuracy: 0.8263999819755554
# Iteration 2 Training accuracy: 0.9106000065803528
# Iteration 2 Testing accuracy: 0.8629999756813049
# 0.03659999370574951
# Iteration 1 Training accuracy: 0.7663999795913696
# Iteration 1 Testing accuracy: 0.8575999736785889
# Iteration 2 Training accuracy: 0.9269999861717224
# Iteration 2 Testing accuracy: 0.9297999739646912
# 0.0722000002861023
# Iteration 1 Training accuracy: 0.758400022983551
# Iteration 1 Testing accuracy: 0.8402000069618225
# Iteration 2 Training accuracy: 0.9276000261306763
# Iteration 2 Testing accuracy: 0.9228000044822693
# 0.08259999752044678
# Iteration 1 Training accuracy: 0.599399983882904
# Iteration 1 Testing accuracy: 0.5198000073432922
# Iteration 2 Training accuracy: 0.9106000065803528
# Iteration 2 Testing accuracy: 0.9175999760627747
# 0.3977999687194824
# Iteration 1 Training accuracy: 0.7760000228881836
# Iteration 1 Testing accuracy: 0.8203999996185303
# Iteration 2 Training accuracy: 0.9179999828338623
# Iteration 2 Testing accuracy: 0.9204000234603882
# 0.10000002384185791
# Iteration 1 Training accuracy: 0.8230000138282776
# Iteration 1 Testing accuracy: 0.8428000211715698
# Iteration 2 Training accuracy: 0.9272000193595886
# Iteration 2 Testing accuracy: 0.9290000200271606
# 0.08619999885559082
# Iteration 1 Training accuracy: 0.7815999984741211
# Iteration 1 Testing accuracy: 0.8525999784469604
# Iteration 2 Training accuracy: 0.8952000141143799
# Iteration 2 Testing accuracy: 0.9124000072479248
# 0.059800028800964355
# Iteration 1 Training accuracy: 0.7057999968528748
# Iteration 1 Testing accuracy: 0.725600004196167
# Iteration 2 Training accuracy: 0.902999997138977
# Iteration 2 Testing accuracy: 0.9150000214576721
# 0.18940001726150513
# Iteration 1 Training accuracy: 0.7121999859809875
# Iteration 1 Testing accuracy: 0.5600000023841858
# Iteration 2 Training accuracy: 0.8934000134468079
# Iteration 2 Testing accuracy: 0.9074000120162964
# 0.3474000096321106
# Iteration 1 Training accuracy: 0.765999972820282
# Iteration 1 Testing accuracy: 0.7990000247955322
# Iteration 2 Training accuracy: 0.8966000080108643
# Iteration 2 Testing accuracy: 0.9143999814987183
# 0.11539995670318604
# Iteration 1 Training accuracy: 0.5171999931335449
# Iteration 1 Testing accuracy: 0.728600025177002
# Iteration 2 Training accuracy: 0.9049999713897705
# Iteration 2 Testing accuracy: 0.9243999719619751
# 0.19579994678497314
# Iteration 1 Training accuracy: 0.7235999703407288
# Iteration 1 Testing accuracy: 0.8379999995231628
# Iteration 2 Training accuracy: 0.8967999815940857
# Iteration 2 Testing accuracy: 0.9114000201225281
# 0.07340002059936523
# Iteration 1 Training accuracy: 0.7850000262260437
# Iteration 1 Testing accuracy: 0.8521999716758728
# Iteration 2 Training accuracy: 0.9017999768257141
# Iteration 2 Testing accuracy: 0.9279999732971191
# 0.07580000162124634
# Iteration 1 Training accuracy: 0.79339998960495
# Iteration 1 Testing accuracy: 0.8349999785423279
# Iteration 2 Training accuracy: 0.9106000065803528
# Iteration 2 Testing accuracy: 0.9240000247955322
# 0.08900004625320435
# Iteration 1 Training accuracy: 0.7603999972343445
# Iteration 1 Testing accuracy: 0.8438000082969666
# Iteration 2 Training accuracy: 0.8952000141143799
# Iteration 2 Testing accuracy: 0.920199990272522
# 0.07639998197555542
# Iteration 1 Training accuracy: 0.7817999720573425
# Iteration 1 Testing accuracy: 0.8288000226020813
# Iteration 2 Training accuracy: 0.902400016784668
# Iteration 2 Testing accuracy: 0.9247999787330627
# 0.09599995613098145
# Iteration 1 Training accuracy: 0.7825999855995178
# Iteration 1 Testing accuracy: 0.6990000009536743
# Iteration 2 Training accuracy: 0.9046000242233276
# Iteration 2 Testing accuracy: 0.9276000261306763
# 0.22860002517700195
# Iteration 1 Training accuracy: 0.7648000121116638
# Iteration 1 Testing accuracy: 0.870199978351593
# Iteration 2 Training accuracy: 0.9031999707221985
# Iteration 2 Testing accuracy: 0.9214000105857849
# 0.051200032234191895
# Iteration 1 Training accuracy: 0.7103999853134155
# Iteration 1 Testing accuracy: 0.8374000191688538
# Iteration 2 Training accuracy: 0.8880000114440918
# Iteration 2 Testing accuracy: 0.926800012588501
# 0.08939999341964722
# Iteration 1 Training accuracy: 0.6890000104904175
# Iteration 1 Testing accuracy: 0.7501999735832214
# Iteration 2 Training accuracy: 0.876800000667572
# Iteration 2 Testing accuracy: 0.9121999740600586
# 0.16200000047683716
# Iteration 1 Training accuracy: 0.6880000233650208
# Iteration 1 Testing accuracy: 0.7968000173568726
# Iteration 2 Training accuracy: 0.855400025844574
# Iteration 2 Testing accuracy: 0.9174000024795532
# 0.12059998512268066
# Iteration 1 Training accuracy: 0.7577999830245972
# Iteration 1 Testing accuracy: 0.8555999994277954
# Iteration 2 Training accuracy: 0.8830000162124634
# Iteration 2 Testing accuracy: 0.9300000071525574
# 0.07440000772476196
# Iteration 1 Training accuracy: 0.7107999920845032
# Iteration 1 Testing accuracy: 0.8338000178337097
# Iteration 2 Training accuracy: 0.8845999836921692
# Iteration 2 Testing accuracy: 0.9214000105857849
# 0.0875999927520752
# Iteration 1 Training accuracy: 0.6769999861717224
# Iteration 1 Testing accuracy: 0.8123999834060669
# Iteration 2 Training accuracy: 0.8550000190734863
# Iteration 2 Testing accuracy: 0.9110000133514404
# 0.09860002994537354
# Iteration 1 Training accuracy: 0.7293999791145325
# Iteration 1 Testing accuracy: 0.8626000285148621
# Iteration 2 Training accuracy: 0.8561999797821045
# Iteration 2 Testing accuracy: 0.9164000153541565
# 0.053799986839294434
# Iteration 1 Training accuracy: 0.6862000226974487
# Iteration 1 Testing accuracy: 0.8058000206947327
# Iteration 2 Training accuracy: 0.8289999961853027
# Iteration 2 Testing accuracy: 0.9093999862670898
# 0.10359996557235718
# Iteration 1 Training accuracy: 0.6912000179290771
# Iteration 1 Testing accuracy: 0.6944000124931335
# Iteration 2 Training accuracy: 0.875
# Iteration 2 Testing accuracy: 0.9110000133514404
# 0.21660000085830688
# Iteration 1 Training accuracy: 0.650600016117096
# Iteration 1 Testing accuracy: 0.8348000049591064
# Iteration 2 Training accuracy: 0.871999979019165
# Iteration 2 Testing accuracy: 0.920199990272522
# 0.08539998531341553
# Iteration 1 Training accuracy: 0.7351999878883362
# Iteration 1 Testing accuracy: 0.8453999757766724
# Iteration 2 Training accuracy: 0.8766000270843506
# Iteration 2 Testing accuracy: 0.9269999861717224
# 0.08160001039505005
# Iteration 1 Training accuracy: 0.6995999813079834
# Iteration 1 Testing accuracy: 0.8378000259399414
# Iteration 2 Training accuracy: 0.8399999737739563
# Iteration 2 Testing accuracy: 0.9082000255584717
# 0.07039999961853027
# Iteration 1 Training accuracy: 0.3140000104904175
# Iteration 1 Testing accuracy: 0.4943999946117401
# Iteration 2 Training accuracy: 0.7842000126838684
# Iteration 2 Testing accuracy: 0.8985999822616577
# 0.4041999876499176
# Iteration 1 Training accuracy: 0.4097999930381775
# Iteration 1 Testing accuracy: 0.6845999956130981
# Iteration 2 Training accuracy: 0.7603999972343445
# Iteration 2 Testing accuracy: 0.8888000249862671
# 0.20420002937316895
# Iteration 1 Training accuracy: 0.5889999866485596
# Iteration 1 Testing accuracy: 0.7585999965667725
# Iteration 2 Training accuracy: 0.8008000254631042
# Iteration 2 Testing accuracy: 0.9178000092506409
# 0.1592000126838684
# Iteration 1 Training accuracy: 0.7080000042915344
# Iteration 1 Testing accuracy: 0.8511999845504761
# Iteration 2 Training accuracy: 0.8514000177383423
# Iteration 2 Testing accuracy: 0.9107999801635742
# 0.059599995613098145
# Iteration 1 Training accuracy: 0.6338000297546387
# Iteration 1 Testing accuracy: 0.852400004863739
# Iteration 2 Training accuracy: 0.8087999820709229
# Iteration 2 Testing accuracy: 0.9300000071525574
# 0.07760000228881836
# Iteration 1 Training accuracy: 0.6340000033378601
# Iteration 1 Testing accuracy: 0.8371999859809875
# Iteration 2 Training accuracy: 0.7943999767303467
# Iteration 2 Testing accuracy: 0.920199990272522
# 0.08300000429153442
# Iteration 1 Training accuracy: 0.6341999769210815
# Iteration 1 Testing accuracy: 0.8058000206947327
# Iteration 2 Training accuracy: 0.8022000193595886
# Iteration 2 Testing accuracy: 0.9114000201225281
# 0.10559999942779541
# Iteration 1 Training accuracy: 0.47839999198913574
# Iteration 1 Testing accuracy: 0.7570000290870667
# Iteration 2 Training accuracy: 0.7445999979972839
# Iteration 2 Testing accuracy: 0.8949999809265137
# 0.13799995183944702
# Iteration 1 Training accuracy: 0.4887999892234802
# Iteration 1 Testing accuracy: 0.715399980545044
# Iteration 2 Training accuracy: 0.7167999744415283
# Iteration 2 Testing accuracy: 0.8777999877929688
# 0.1624000072479248
# Iteration 1 Training accuracy: 0.49900001287460327
# Iteration 1 Testing accuracy: 0.7576000094413757
# Iteration 2 Training accuracy: 0.6980000138282776
# Iteration 2 Testing accuracy: 0.9147999882698059
# 0.15719997882843018
# Iteration 1 Training accuracy: 0.5541999936103821
# Iteration 1 Testing accuracy: 0.8148000240325928
# Iteration 2 Training accuracy: 0.696399986743927
# Iteration 2 Testing accuracy: 0.9103999733924866
# 0.0955999493598938
# Iteration 1 Training accuracy: 0.4862000048160553
# Iteration 1 Testing accuracy: 0.7588000297546387
# Iteration 2 Training accuracy: 0.6899999976158142
# Iteration 2 Testing accuracy: 0.8984000086784363
# 0.1395999789237976
# Iteration 1 Training accuracy: 0.43779999017715454
# Iteration 1 Testing accuracy: 0.72079998254776
# Iteration 2 Training accuracy: 0.7152000069618225
# Iteration 2 Testing accuracy: 0.902400016784668
# 0.18160003423690796
# Iteration 1 Training accuracy: 0.5508000254631042
# Iteration 1 Testing accuracy: 0.7968000173568726
# Iteration 2 Training accuracy: 0.7235999703407288
# Iteration 2 Testing accuracy: 0.9125999808311462
# 0.11579996347427368
# Iteration 1 Training accuracy: 0.4699999988079071
# Iteration 1 Testing accuracy: 0.7839999794960022
# Iteration 2 Training accuracy: 0.604200005531311
# Iteration 2 Testing accuracy: 0.8925999999046326
# 0.10860002040863037
# Iteration 1 Training accuracy: 0.5428000092506409
# Iteration 1 Testing accuracy: 0.8094000220298767
# Iteration 2 Training accuracy: 0.6237999796867371
# Iteration 2 Testing accuracy: 0.8967999815940857
# 0.08739995956420898
# Iteration 1 Training accuracy: 0.46720001101493835
# Iteration 1 Testing accuracy: 0.7996000051498413
# Iteration 2 Training accuracy: 0.6097999811172485
# Iteration 2 Testing accuracy: 0.8974000215530396
# 0.09780001640319824
# Iteration 1 Training accuracy: 0.3662000000476837
# Iteration 1 Testing accuracy: 0.7361999750137329
# Iteration 2 Training accuracy: 0.5685999989509583
# Iteration 2 Testing accuracy: 0.8884000182151794
# 0.15220004320144653
# Iteration 1 Training accuracy: 0.4918000102043152
# Iteration 1 Testing accuracy: 0.777999997138977
# Iteration 2 Training accuracy: 0.6273999810218811
# Iteration 2 Testing accuracy: 0.8988000154495239
# 0.12080001831054688
